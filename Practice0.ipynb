# %% [markdown]
# **Practice Only No Copy and Paste from any sources.**

# %% [markdown]
# #Read the dataset (propertydata.csv) and identify the columns and their datatype

# %%
import pandas as pd

# %%
xt1778=pd.read_csv('propertydata.csv')
xt1778
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED NUM_BEDROOMS NUM_BATH SQ_FT
# 0  100001000.0   104.0      PUTNAM            Y            3        1  1000
# 1  100002000.0   197.0   LEXINGTON            N            3      1.5    --
# 2  100003000.0     NaN   LEXINGTON            N          NaN        1   850
# 3  100004000.0   201.0    BERKELEY           12            1      NaN   700
# 4          NaN   203.0    BERKELEY            Y            3        2  1600
# 5  100006000.0   207.0    BERKELEY            Y          NaN        1   800
# 6  100007000.0     NaN  WASHINGTON          NaN            2   HURLEY   950
# 7  100008000.0   213.0     TREMONT            Y            1        1   NaN
# 8  100009000.0   215.0     TREMONT            Y           na        2  1800

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #Describe the dataset

# %%
xt1778.shape
# Out:
# (9, 7)

# %%
xt1778.describe #.describe is used to represent all the values in the dataframe again
# Out:
# <bound method NDFrame.describe of            PID  ST_NUM     ST_NAME OWN_OCCUPIED NUM_BEDROOMS NUM_BATH SQ_FT
# 0  100001000.0   104.0      PUTNAM            Y            3        1  1000
# 1  100002000.0   197.0   LEXINGTON            N            3      1.5    --
# 2  100003000.0     NaN   LEXINGTON            N          NaN        1   850
# 3  100004000.0   201.0    BERKELEY           12            1      NaN   700
# 4          NaN   203.0    BERKELEY            Y            3        2  1600
# 5  100006000.0   207.0    BERKELEY            Y          NaN        1   800
# 6  100007000.0     NaN  WASHINGTON          NaN            2   HURLEY   950
# 7  100008000.0   213.0     TREMONT            Y            1        1   NaN
# 8  100009000.0   215.0     TREMONT            Y           na        2  1800>

# %%
xt1778.describe() #there is a difference between describe() and describe
                  #but describe() shows only the stastical analysis of cloumns with numerical vaues only
# Out:
#                 PID      ST_NUM
# count  8.000000e+00    7.000000
# mean   1.000050e+08  191.428571
# std    2.927700e+03   39.080503
# min    1.000010e+08  104.000000
# 25%    1.000028e+08  199.000000
# 50%    1.000050e+08  203.000000
# 75%    1.000072e+08  210.000000
# max    1.000090e+08  215.000000

# %% [markdown]
# #Display the street number (ST_NUM) and check any NaN values.

# %%
xt1778['ST_NUM']
# Out:
# 0    104.0
# 1    197.0
# 2      NaN
# 3    201.0
# 4    203.0
# 5    207.0
# 6      NaN
# 7    213.0
# 8    215.0
# Name: ST_NUM, dtype: float64

# %%
xt1778['ST_NUM'].isnull()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# 5    False
# 6     True
# 7    False
# 8    False
# Name: ST_NUM, dtype: bool

# %% [markdown]
# #Print the number of bedrooms (NUM_BEDROOMS) and check any NaN values.

# %%
xt1778['NUM_BEDROOMS']
# Out:
# 0      3
# 1      3
# 2    NaN
# 3      1
# 4      3
# 5    NaN
# 6      2
# 7      1
# 8     na
# Name: NUM_BEDROOMS, dtype: object

# %%
xt1778['NUM_BEDROOMS'].isnull().sum(axis=0) #with additional sum() call with argument of axis defines its column
# Out:
# 2

# %%
xt1778['NUM_BEDROOMS'].isnull()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# 5     True
# 6    False
# 7    False
# 8    False
# Name: NUM_BEDROOMS, dtype: bool

# %% [markdown]
# #There are few missing values like ["n/a", "na",  "--"] Apply some technique to replace these values with NaN.

# %%
xt1778 #before applying the editing
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED NUM_BEDROOMS NUM_BATH SQ_FT
# 0  100001000.0   104.0      PUTNAM            Y            3        1  1000
# 1  100002000.0   197.0   LEXINGTON            N            3      1.5    --
# 2  100003000.0     NaN   LEXINGTON            N          NaN        1   850
# 3  100004000.0   201.0    BERKELEY           12            1      NaN   700
# 4          NaN   203.0    BERKELEY            Y            3        2  1600
# 5  100006000.0   207.0    BERKELEY            Y          NaN        1   800
# 6  100007000.0     NaN  WASHINGTON          NaN            2   HURLEY   950
# 7  100008000.0   213.0     TREMONT            Y            1        1   NaN
# 8  100009000.0   215.0     TREMONT            Y           na        2  1800

# %%
tt = ['n/a', 'na', '--']

xt1778.replace(tt, float('NaN'), inplace=True)

# %%
xt1778
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED NUM_BEDROOMS NUM_BATH SQ_FT
# 0  100001000.0   104.0      PUTNAM            Y            3        1  1000
# 1  100002000.0   197.0   LEXINGTON            N            3      1.5   NaN
# 2  100003000.0   215.0   LEXINGTON            N          NaN        1   850
# 3  100004000.0   201.0    BERKELEY           12            1      NaN   700
# 4          NaN   203.0    BERKELEY            Y            3        2  1600
# 5  100006000.0   207.0    BERKELEY            Y          NaN        1   800
# 6  100007000.0   215.0  WASHINGTON          NaN            2   HURLEY   950
# 7  100008000.0   213.0     TREMONT            Y            1        1   NaN
# 8  100009000.0   215.0     TREMONT            Y          NaN        2  1800

# %% [markdown]
# Fill the ST_NUM by the maximum Street number of houses in a particular street

# %%
xt1778['ST_NUM'].max()
# Out:
# 215.0

# %%
xt1778['ST_NUM'].fillna(xt1778['ST_NUM'].max(), inplace=True)
xt1778
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED NUM_BEDROOMS NUM_BATH SQ_FT
# 0  100001000.0   104.0      PUTNAM            Y            3        1  1000
# 1  100002000.0   197.0   LEXINGTON            N            3      1.5   NaN
# 2  100003000.0   215.0   LEXINGTON            N          NaN        1   850
# 3  100004000.0   201.0    BERKELEY           12            1      NaN   700
# 4          NaN   203.0    BERKELEY            Y            3        2  1600
# 5  100006000.0   207.0    BERKELEY            Y          NaN        1   800
# 6  100007000.0   215.0  WASHINGTON          NaN            2   HURLEY   950
# 7  100008000.0   213.0     TREMONT            Y            1        1   NaN
# 8  100009000.0   215.0     TREMONT            Y          NaN        2  1800
